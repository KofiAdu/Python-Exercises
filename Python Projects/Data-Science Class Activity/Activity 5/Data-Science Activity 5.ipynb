# %% [markdown]
# ## matplotlib Programming Activity
#
#
# For this exercise, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# ![Image 1](images/company_sales_data.png)
#
# Use the following CSV file located in the data folder in this jupyter activity for this exercise. Read this file using Pandas or NumPy or using in-built matplotlib function.
#
# This exercise contains ten questions. The solution provided for each issue. Each question includes a specific Matplotlib topic you need to learn, When you complete each issue you get more familiar with Data data visualization using matplotlib.

# %% [markdown]
# ## Exercise 1: Read Total profit of all months and show it using a line plot
#
# In this activity your will provide the total profit data provided for each month. The generated line plot must include the following properties: –
#
# X label name = Month Number
# Y label name = Total profit
# The line plot graph should look like this.
#
# ![Image 1](images/e1.png)

# %%
# Excercise 1

#Start Code 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df= pd.read_csv("company_sales_data.csv")
df

plt.plot(df["month_number"],df["total_profit"])



plt.xlim((1,12))
plt.ylim((100000,500000))

plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("Company Sales Data")


#end code
# Out:
# Text(0.5, 1.0, 'Company Sales Data')

# %% [markdown]
# ## Exercise Question 2: Get Total profit of all months and show line plot with the following Style properties
#
# Generated line plot must include following Style properties:
#
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this.
# ![Image 1](images/e2.png)

# %%
# Excercise 2

#Start Code 


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

df= pd.read_csv("company_sales_data.csv")
df

plt.plot(df["month_number"],df["total_profit"])
x=df['month_number']
y=df['total_profit']
plt.plot(x,y,'b-','go',linewidth=3,color='red',marker='o')

plt.xlim((1,12))
plt.ylim((100000,500000))


plt.xlabel("Month Number")
plt.ylabel("Total Profit")
plt.title("Company Sales Data")


csd = mpatches.Patch(color='red', label='Profit Data of Last Year',)
plt.legend(handles=[csd],loc='lower right')



#end code

# %% [markdown]
# ## Exercise Question 3: Read all product sales data and show it  using a multiline plot
#
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.
#
# ![Image3](images/e3.png)

# %%
# Excercise 3

#Start Code 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df= pd.read_csv("company_sales_data.csv")
df

tp=df[['toothpaste']]
fc=df[['facecream']]
fw=df[['facewash']]
sh=df[['shampoo']]
bs=df[['bathingsoap']]
m =df[['moisturizer']]

x=df[['month_number']]


plt.plot(x,tp,'g',label="Toothpaste Sales Data",lw=3,marker='o')
plt.plot(x,fc,'b',label="Facecream Sales Data",lw=3,marker='o')
plt.plot(x,fw,'brown',label="Facewash Sales Data",lw=3,marker='o')
plt.plot(x,sh,'purple',label="Shampoo Sales Data",lw=3,marker='o')
plt.plot(x,bs,'r',label="Bathingsoap Sales Data",lw=3,marker='o')
plt.plot(x,m,'v',label="Moisturizer Sales Data",lw=3,marker='o')

plt.xlabel("Months")
plt.ylabel("Sales units in numbers")
plt.title("Sales")

plt.legend(('Toothpaste Sales Data','Facecream Sales Data',"Facewash Sales Data","Shampoo Sales Data","Bathingsoap Sales Data"))

#end code

# %% [markdown]
# ## Exercise Question 4: Read toothpaste sales data of each month and show it using a scatter plot
#
# Also, add a grid in the plot. gridline style should “–“.
#
# The scatter plot should look like this.
#
# ![Image 4](images/e4.png)

# %%
# Excercise 4

#Start Code 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


tpsd= pd.read_csv("company_sales_data.csv")
y=tpsd[['toothpaste']]

m=tspd[['month_number']]
x=m
plt.scatter(x,y)

plt.grid(ls='--')

plt.legend(('Toothpaste Sales Data'),loc='upper left')

plt.xlabel("Months")
plt.ylabel("Sales units in numbers")
plt.title("Toothpaste Sales Data")

#end code
# Out:
# Text(0.5, 1.0, 'Toothpaste Sales Data')

# %% [markdown]
# Exercise Question 5: Read face cream and facewash product sales data and show it using the bar chart
#
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.
#
# ![Image 5](images/e5.png)

# %%
# Excercise 5

#Start Code 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("company_sales_data.csv")

plt.bar(df['month_number'],df['facecream'],width=0.3)

plt.bar(df['month_number']+0.3,df['facewash'],width=0.3)

plt.grid(ls='--')

plt.xlabel("Months")
plt.ylabel("Sales units in numbers")
plt.title("Facecream and Facewash Sales")

plt.legend(('Facecream Sales Data',"Facewash Sales Data"),loc='upper left')
#end code

# %% [markdown]
# ## Exercise Question 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# The bar chart should look like this.
#
# ![image 6](images/e6.png)

# %%
# Excercise 6

#Start Code 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("company_sales_data.csv")


plt.bar(df['month_number'],df['bathingsoap'],width=0.5)



plt.grid(ls='--')

plt.xlabel("Months")
plt.ylabel("Sales units in numbers")
plt.title("Bathing Soap Sales")




#end code
# Out:
# Text(0.5, 1.0, 'Bathing Soap Sales')

# %% [markdown]
# ## Exercise Question 7: Read the total profit of each month and show it using the histogram to see most common profit ranges
#
# The histogram should look like this.
#
# ![image 7](images/e7.png)

# %%
# Excercise 7

#Start Code 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("company_sales_data.csv")

df[['total_profit']]


plt.hist(df['total_profit'])






#end code
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Exercise Question 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this.
#
# ![Image 8](images/e8.png)

# %%
# Excercise 8

#Start Code 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("company_sales_data.csv")
df

df


#end code
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ## Exercise Question 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# The Subplot should look like this.
#
# ![image 9](images/e9.png)

# %%
# Excercise 9

#Start Code 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df= pd.read_csv("company_sales_data.csv")
df
bs=df[['bathingsoap']]
fw=df[['facewash']]

fig=plt.figure()

axis1= fig.add_subplot(211)
plt.plot(bs,linewidth=3,marker='o')
axis1.set_title("Sales Data for Bathing Soap")


axis2= fig.add_subplot(212)
plt.plot(fw,lw=3,marker='o')
axis2.set_title("Sales Data for Facewash")

#end code
# Out:
# Text(0.5, 1.0, 'Sales Data for Facewash')

# %% [markdown]
# ## Exercise Question 10: Read all product sales data and show it using the stack plot
#
# The Stack plot should look like this.
#
# ![Image 10](images/e10.png)

# %%
# Excercise 10

#Start Code 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df= pd.read_csv("company_sales_data.csv")
df

#tp=df[['toothpaste']]
#fc=df[['facecream']]
#fw=df[['facewash']]
#bs=df[['bathingsoap']]
#m =df[['moisturizer']]

#x=df[['month_number']]

plt.plot([],[], color='b',label='facecream')
plt.plot([],[], color='orange',label='facewash')
plt.plot([],[], color='g',label='toothpaste')
plt.plot([],[], color='r',label='bathingsoap')
plt.plot([],[], color='purple',label='shampoo')
plt.plot([],[], color='brown',label='moisturizer')

plt.stackplot(df['month_number'],df['facecream'],df['facewash'],df['toothpaste'],df['bathingsoap'],df['shampoo'],df['moisturizer'])


plt.xlabel("Months")
plt.ylabel("Sales units in numbers")
plt.title("All sales product data using a stackplot")

plt.legend(loc='upper left')

plt.show()




#end code
